# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Plate type'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00117030', variable : 'Cell Carrier Ultra - No barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117030'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117030')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117031', variable : 'Cell Carrier Ultra - No barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117031'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117031')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117032', variable : 'Cell Carrier Ultra - No barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117032'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117032')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117143', variable : 'Aurora - barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117143'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117143')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117144', variable : 'Aurora - barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117144'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117144')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR0011750', variable : 'Aurora - barrier wells', 
'Batch' : 'Plate1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117150'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_07_Plate1','BR00117150')}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,y='Percent Replicating',hue='Batch')
# Out:
# Saved to ../figures/Plate type-Percent Replicating-Batch-None-None.png

# %%
plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[0.05,0.4])
# Out:
# Saved to ../figures/Plate type-Percent Matching-Batch-None-None.png

# %%
plot_two_comparisons(df=plate_df,hue=variable,title_variable=variable,facet_kws={'legend_out':False})
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Plate type-None-None-None.png

# %%
plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)
