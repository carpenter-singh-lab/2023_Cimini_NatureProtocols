# %%
# !python3.8 --version
# Out:
# Python 3.8.13

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Multiplane'
variable_to_save = variable.replace(' ','_')

# %%
os.listdir('../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard/BR00112197')
df = pandas.read_csv('../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard/BR00112197/BR00112197.csv.gz')

# %%
plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00112197', variable : 'No', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112197',indiv=True), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112197')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112198', variable : 'No', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112198',indiv=True), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112198')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112199', variable : 'Yes', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Multiplane','BR00112199',indiv=True), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Multiplane','BR00112199')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115134', variable : 'No', 'Batch' : 'Stain3', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115134',indiv=True), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115134')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115134', variable : 'Yes', 'Batch' : 'Stain3', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Multiplane','BR00115134',indiv=True), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Multiplane','BR00115134')}, ignore_index=True)
# Out:
# /var/folders/8t/hj0jrcld7sjbfvg6svqpwggr0000gq/T/ipykernel_81375/2663344195.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   plate_df = plate_df.append({'Plate Name' : 'BR00112197', variable : 'No', 'Batch' : 'Stain2',
# /var/folders/8t/hj0jrcld7sjbfvg6svqpwggr0000gq/T/ipykernel_81375/2663344195.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   plate_df = plate_df.append({'Plate Name' : 'BR00112198', variable : 'No', 'Batch' : 'Stain2',
# /var/folders/8t/hj0jrcld7sjbfvg6svqpwggr0000gq/T/ipykernel_81375/2663344195.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   plate_df = plate_df.append({'Plate Name' : 'BR00112199', variable : 'Yes', 'Batch' : 'Stain2',
# ...

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
from utils import plot_simple_comparison_with_errorbars

plot_simple_comparison_with_errorbars(df=plate_df,x=variable,y='Percent Replicating',hue='Plate Name')
# Out:
# Saved to ../figures/Multiplane-Percent Replicating-Plate Name-None-None.png

# %%
#plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[5,40])

# %%
#plot_two_comparisons(df=plate_df,hue='Batch',style=variable,title="Single vs Multiple planes")

# %%
#plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)
