# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Imaging modality'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00112197', variable : 'Widefield', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112197'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112197')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112198', variable : 'Widefield', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112198'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112198')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112200', variable : 'Confocal (4 Channels)', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Confocal','BR00112200'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Confocal','BR00112200')}, ignore_index=True)

for eachplate in range(23,31):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', 
    variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(23,31):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', 
    variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Confocal',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Confocal',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(31,39):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', 
    variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(31,39):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', 
    variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Confocal',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Confocal',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(70,78):
    plate_df = plate_df.append({'Plate Name' : f'BR001202{eachplate}', 
    variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}')}, ignore_index=True)

for eachplate in range(70,78):
    plate_df = plate_df.append({'Plate Name' : f'BR001202{eachplate}', 
    variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Confocal',f'BR001202{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Confocal',f'BR001202{eachplate}')}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,y='Percent Replicating',hue='Batch')
# Out:
# Saved to ../figures/Imaging modality-Percent Replicating-Batch-None-None.png

# %%
plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[5,40])
# Out:
# Saved to ../figures/Imaging modality-Percent Matching-Batch-None-None.png

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable, col_order=['Widefield','Confocal (5 Channels)'])
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Imaging modality-None-None.png

# %%
plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)

# %%
# !python3.8 --version
# Out:
# Python 3.8.15

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Imaging modality'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.read_csv(f'checkpoint_csvs/{variable_to_save}.csv')

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable, col_order=['Widefield','Confocal (5 Channels)'])
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Imaging modality-None-None.svg
