# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_replicating_Target, plot_simple_comparison

# %%
variable = 'Imaging modality'

plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00112197', variable : 'Widefield', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112197')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112198', variable : 'Widefield', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Standard','BR00112198')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00112200', variable : 'Confocal (4 Channels)', 'Batch' : 'Stain2', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_06_25_Stain2_Batch2_Confocal','BR00112200')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120523', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120523')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120524', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120524')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120525', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120525')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120526', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120526')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120527', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120527')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120528', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120528')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120529', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120529')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120530', variable : 'Widefield', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120530')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120531', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120531')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120532', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120532')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120533', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120533')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120534', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120534')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120535', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120535')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120536', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120536')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120537', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120537')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120538', variable : 'Widefield', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Standard','BR00120538')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120270', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120270')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120271', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120271')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120272', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120272')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120273', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120273')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120274', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120274')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120275', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120275')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120276', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120276')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120277', variable : 'Widefield', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Standard','BR00120277')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120523', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120523')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120524', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120524')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120525', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120525')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120526', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120526')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120527', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120527')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120528', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120528')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120529', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120529')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120530', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondA', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120530')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120531', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120531')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120532', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120532')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120533', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120533')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120534', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120534')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120535', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120535')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120536', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120536')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120537', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120537')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120538', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondB', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondAB_Confocal','BR00120538')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120270', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120270')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120271', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120271')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120272', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120272')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120273', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120273')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120274', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120274')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120275', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120275')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120276', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120276')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00120277', variable : 'Confocal (5 Channels)', 'Batch' : 'Stain5-CondC', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/Stain5_CondC_Confocal','BR00120277')}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,hue='Batch')
# Out:
# Saved to ../figures/Imaging modality-Batch.png
