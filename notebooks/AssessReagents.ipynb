# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Reagent source'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.DataFrame()

for eachplate in range(1,5):
    plate_df = plate_df.append({'Plate Name' : f'CPJUMP00{eachplate}', variable : 'ThermoFisher', 'Batch' : 'Reagent1', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/2020_12_11_Reagent1_Pfizer',f'CPJUMP00{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/2020_12_11_Reagent1_Pfizer',f'CPJUMP00{eachplate}')}, ignore_index=True)

for eachplate in range(5,9):
    plate_df = plate_df.append({'Plate Name' : f'CPJUMP00{eachplate}', variable : 'PerkinElmer', 'Batch' : 'Reagent1', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/2020_12_11_Reagent1_Pfizer',f'CPJUMP00{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/2020_12_11_Reagent1_Pfizer',f'CPJUMP00{eachplate}')}, ignore_index=True)

for eachplate in range(23,27):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', variable : 'ThermoFisher', 'Batch' : 'Stain5-CondA-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(27,31):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', variable : 'PerkinElmer', 'Batch' : 'Stain5-CondA-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in ['1031173374','1031173381','1031173404']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'ThermoFisher', 'Batch' : 'Stain5-CondA-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

for eachplate in ['1031173343','1031173336','1031173329','1031173312']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'PerkinElmer', 'Batch' : 'Stain5-CondA-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

for eachplate in range(31,35):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', variable : 'ThermoFisher', 'Batch' : 'Stain5-CondB-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in range(35,39):
    plate_df = plate_df.append({'Plate Name' : f'BR001205{eachplate}', variable : 'PerkinElmer', 'Batch' : 'Stain5-CondB-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondAB_Standard',f'BR001205{eachplate}')}, ignore_index=True)

for eachplate in ['1031173411','1031173428','1031173435','1031173442']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'ThermoFisher', 'Batch' : 'Stain5-CondB-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

for eachplate in ['1031173305','1031173299','1031173282','1031173275']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'PerkinElmer', 'Batch' : 'Stain5-CondB-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

for eachplate in range(70,74):
    plate_df = plate_df.append({'Plate Name' : f'BR001202{eachplate}', variable : 'ThermoFisher', 'Batch' : 'Stain5-CondC-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}')}, ignore_index=True)

for eachplate in range(74,78):
    plate_df = plate_df.append({'Plate Name' : f'BR001202{eachplate}', variable : 'PerkinElmer', 'Batch' : 'Stain5-CondC-Broad', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}'), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_CondC_Standard',f'BR001202{eachplate}')}, ignore_index=True)

for eachplate in ['1031173459','1031173466','1031173367','1031173350']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'ThermoFisher', 'Batch' : 'Stain5-CondC-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

for eachplate in ['1031173268','1031173251','1031173244','1031173237']:
    plate_df = plate_df.append({'Plate Name' : eachplate, variable : 'PerkinElmer', 'Batch' : 'Stain5-CondC-AZ', 
    'Percent Replicating' : calculate_percent_replicating_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate), 
    'Percent Matching' : calculate_percent_matching_MOA(
        '../profiles-pilots/profiles/Stain5_AZ',eachplate)}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,y='Percent Replicating',hue='Batch')
# Out:
# Saved to ../figures/Reagent source-Percent Replicating-Batch-None-None.png

# %%
plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[5,40])
# Out:
# Saved to ../figures/Reagent source-Percent Matching-Batch-None-None.png

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable)
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Reagent source-None-None.png

# %%
plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)

# %%
# !python3.8 --version
# Out:
# Python 3.8.15

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Reagent source'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.read_csv(f'checkpoint_csvs/{variable_to_save}.csv')

# %%
plot_two_comparisons(df=plate_df,hue='Batch',style=variable)
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-None-None-Reagent source.svg
