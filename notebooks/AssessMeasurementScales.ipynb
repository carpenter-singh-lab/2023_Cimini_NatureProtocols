# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Measurement scales'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00117095', variable : 'Smaller', 'Batch' : 'Cell1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged','BR00117095'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged','BR00117095')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117096', variable : 'Smaller', 'Batch' : 'Cell1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged','BR00117096'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged','BR00117096')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117095', variable : 'Larger', 'Batch' : 'Cell1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged_Bin1Pipeline','BR00117095'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged_Bin1Pipeline','BR00117095')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00117096', variable : 'Larger', 'Batch' : 'Cell1', 
'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged_Bin1Pipeline','BR00117096'), 
'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_10_20_Cell1_restainedReimaged_Bin1Pipeline','BR00117096')}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,y='Percent Replicating',hue='Batch')
# Out:
# Saved to ../figures/Measurement scales-Percent Replicating-Batch-None-None.png

# %%
plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[0.05,0.4])
# Out:
# Saved to ../figures/Measurement scales-Percent Matching-Batch-None-None.png

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable)
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Measurement scales-None.png

# %%
plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)
