# %%
# !python3 --version
# Out:
# Python 3.8.11

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Microscope'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.DataFrame()

plate_df = plate_df.append({'Plate Name' : 'BR00115134', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondA', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115134'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115134')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115133', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondB', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115133'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115133')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115132', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondC', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115132'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115132')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115131', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondD', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115131'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115131')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115129', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondE', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115129'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115129')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115128', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondF', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115128'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115128')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115127', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondG', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115127'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115127')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115126', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondH', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115126'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115126')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115125', variable : 'Microscope A, Widefield, 2x2 binned', 
'Batch' : 'StainCondI', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115125'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Standard','BR00115125')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115134', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondA', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115134'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115134')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115133', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondB', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115133'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115133')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115132', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondC', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115132'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115132')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115131', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondD', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115131'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115131')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115129', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondE', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115129'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115129')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115128', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondF', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115128'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115128')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115127', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondG', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115127'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115127')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115126', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondH', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115126'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115126')}, ignore_index=True)

plate_df = plate_df.append({'Plate Name' : 'BR00115125', variable : 'Microscope B, Confocal, 1x1 binned', 
'Batch' : 'StainCondI', 'Percent Replicating' : calculate_percent_replicating_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115125'), 
    'Percent Matching' : calculate_percent_matching_MOA(
    '../profiles-pilots/profiles/2020_08_11_Stain3_Yokogawa','BR00115125')}, ignore_index=True)

# %%
#You may find that running this a couple of times is needed to find a version where the jitter is about right
plot_simple_comparison(df=plate_df,x=variable,y='Percent Replicating',hue='Batch')
# Out:
# Saved to ../figures/Microscope-Percent Replicating-Batch-None-None.png

# %%
plot_simple_comparison(df=plate_df,x=variable,y='Percent Matching',hue='Batch',ylim=[5,40])
# Out:
# Saved to ../figures/Microscope-Percent Matching-Batch-None-None.png

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable)
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Microscope-None-None.png

# %%
plate_df.to_csv(f'checkpoint_csvs/{variable_to_save}.csv',index=False)

# %%
# !python3.8 --version
# Out:
# Python 3.8.15

# %%
import pandas

from utils import calculate_percent_replicating_MOA, calculate_percent_matching_MOA
from utils import plot_simple_comparison, plot_two_comparisons

# %%
variable = 'Microscope'
variable_to_save = variable.replace(' ','_')

# %%
plate_df = pandas.read_csv(f'checkpoint_csvs/{variable_to_save}.csv')

# %%
plot_two_comparisons(df=plate_df,hue='Batch',col=variable)
# Out:
# Saved to ../figures/Percent Replicating-Percent Matching-Batch-Microscope-None-None.svg
